# %%
from colored_networks.network import *
from colored_networks.lambda_calc import *

# %%
# Define constants
id = Abs("x", Var("x"))
true = Abs("x", Abs("y", Var("x")))
false = Abs("x", Abs("y", Var("y")))

# %%
id_id = App(id.clone(), id.clone())
net = id_id.to_colored_network()
net.reduce(verbose=True)
# Out:
# Applying rule 'beta reduction (lambda)' to node Node(id=0, label='λx')
# Applying rule 'beta reduction (app)' to node Node(id=6, label='⋅')
# Applying rule 'duplicate' to node Node(id=1, label='Δ')
# Applying rule 'var substitution (root)' to node Node(id=2, label='x')

# %%
net = App(App(true.clone(), true.clone()), false.clone()).to_colored_network()
net.reduce(verbose=True)
# Out:
# Applying rule 'beta reduction (lambda)' to node Node(id=0, label='λx')
# Applying rule 'beta reduction (app) as left child' to node Node(id=10, label='⋅')
# Applying rule 'duplicate' to node Node(id=1, label='Δ')
# Applying rule 'var substitution as lambda body' to node Node(id=4, label='x')
# Applying rule 'beta reduction (lambda)' to node Node(id=2, label='λy')
# Applying rule 'beta reduction (app)' to node Node(id=16, label='⋅')
# Applying rule 'detect deletion' to node Node(id=3, label='Δ')
# Applying rule 'delete lambda' to node Node(id=11, label='λx')
# Applying rule 'delete lambda' to node Node(id=13, label='λy')
# Applying rule 'delete variable' to node Node(id=15, label='y')

# %%
duplication = App(Abs("x", App(Var("x"), Var("x"))), id.clone())
net = duplication.to_colored_network()
net.reduce(verbose=True)
# Out:
# Applying rule 'beta reduction (lambda)' to node Node(id=0, label='λx')
# Applying rule 'beta reduction (app)' to node Node(id=9, label='⋅')
