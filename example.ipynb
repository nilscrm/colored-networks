# %%
from colored_graphs.colored_graph import *
from colored_graphs.lambda_calc import *

# %%
# Define constants
id = Abs("x", Var("x"))
true = Abs("x", Abs("y", Var("x")))
false = Abs("x", Abs("y", Var("y")))

# %%
id_id = App(id.clone(), id.clone())
net = id_id.to_colored_network()
net.reduce(verbose=True)
# Out:
# Applying rule 0
# Applying rule 1
# Applying rule 2
# Applying rule 3

# %%
net = App(App(true.clone(), true.clone()), false.clone()).to_colored_network()
net.reduce(verbose=True)
# Out:
# Applying rule 0
